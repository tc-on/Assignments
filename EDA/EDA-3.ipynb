# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
adult = pd.read_csv('adult.csv')
adult.head()
# Out:
#    age workclass  fnlwgt  ... hours.per.week  native.country income
# 0   90         ?   77053  ...             40   United-States  <=50K
# 1   82   Private  132870  ...             18   United-States  <=50K
# 2   66         ?  186061  ...             40   United-States  <=50K
# 3   54   Private  140359  ...             40   United-States  <=50K
# 4   41   Private  264663  ...             40   United-States  <=50K
#
# [5 rows x 15 columns]

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(10,8))
sns.scatterplot(x='age',y='hours.per.week',data=adult)
plt.show()

# %% [markdown]
# - From the scatterplot we can see that there is no correlation between age and working hours.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x='education.num',y='capital.gain',data=adult)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - To see the trend in rise of capital gain, we can observe the education qualification increases so does the capital gain. With some outliers with no education.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='hours.per.week',y='capital.gain',data=adult)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - From the scatterplot, we can see that most individuals with working hours per week between 40 and 60 enjoy a considerable amount of capital gain with a few outliers in the dataset with the maximum amount of capital gain irrespective of working hours.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x=adult['age'],y=adult['hours.per.week'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - We can see with the trend that the work hours remain consistent wwithin ages of 30 to 60 after which the hours per week reduces for individuals above the age of 60, all the while containing some outliers having the same working hours as the projected working age group stated above.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x='age',y=adult['capital.loss'],data=adult)
plt.show()

# %% [markdown]
# - From the trend line through the line graph we can observe the capital loss increasing as the age increases.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df = adult[['capital.gain','age']]
print(df.corr())
print('\n')
plt.figure(figsize=(10,8))
sns.scatterplot(data=adult,x='capital.gain',y='age')
plt.show()
# Out:
#               capital.gain       age
# capital.gain      1.000000  0.077674
# age               0.077674  1.000000

# %% [markdown]
# - No, the scatterplot produced in the above graph shows no negative relation between capital gain and age.

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='income', y='age',data=adult)
plt.show()

# %% [markdown]
# - As the average age increases so does the capital gain.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x=adult['sex'],y=adult['hours.per.week'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - From the violin plot we can observe that, for both females and males at the age of 40 have the same distributions in working hours per week.
# - From the tail ending of Female violin plot, we can see it having more distribuiton for working hours per week lesser than 40 hours.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df1 = pd.crosstab(adult['education'],adult['income'])
df1.plot(kind='bar',figsize=(10,8))
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Most of the individuals who earn less than 50k have an education qualification of HS-grad, which in contrast is also the second highest frequency to earn more than 50k.
# - The above graphs shows the workforce not the individuals.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(adult['age'].groupby(adult['sex']).mean())
print('\n')
adult['age'].groupby(adult['sex']).mean().plot(kind='bar',figsize=(10,8))
plt.show()
# Out:
# sex
# Female    36.858230
# Male      39.433547
# Name: age, dtype: float64

# %% [markdown]
# - From the plot above we can observe the average age of Females is closer to 36 and for Males it is closer to 39.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8))
sns.violinplot(data=adult,x='income',y='hours.per.week')
plt.show()

# %% [markdown]
# - From the above plot we can observe that, both the income groups have similar amount of distributions near 40 hours per week.
# - We can see the income group having less than 50k income getting more distributions with working hours per week less than 40.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data=adult,x ='sex',y='age',hue='race')
plt.show()

# %% [markdown]
# - All the distributions are positively skewed.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='workclass',y='hours.per.week',data=adult)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y = adult['hours.per.week'],x=adult['workclass'],data=adult)
plt.show()

# %% [markdown]
# - From the above plot we can confer that the self employed spends more hours per week for work.
# - Without pay and never-worked works the least hours per week with some outliers present.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.pivot_table(adult,index='native.country',columns='sex',values='fnlwgt',aggfunc='mean').plot(kind='bar',figsize=(25,15))
plt.show()

# %% [markdown]
# - Nicaragua individuals have the most weightage out of all.
# - By a unique characteristic, the only country with females with the most weightage is Trinidad and Tobago.

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
adultct = pd.crosstab(adult['sex'],adult['income']).apply(lambda x: (x/x.sum()),axis=1)
print(adultct)
print('\n')
adultct.plot(kind='bar',stacked=True, figsize=(10,8))
plt.xticks(rotation=0)
plt.show()
# Out:
# income     <=50K      >50K
# sex
# Female  0.890539  0.109461
# Male    0.694263  0.305737

# %% [markdown]
# - From the above plot we can confer that males earn more with respect to their frequency in the income group of >50K.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(pd.crosstab(adult['race'],adult['income']))
print('\n')
pd.crosstab(adult['race'],adult['income']).plot(kind='bar',figsize=(15,8),)
plt.xticks(rotation=0)
plt.show()
# Out:
# income              <=50K  >50K
# race
# Amer-Indian-Eskimo    275    36
# Asian-Pac-Islander    763   276
# Black                2737   387
# Other                 246    25
# White               20699  7117

# %% [markdown]
# - From the plot, the White race earns the most with the most individuals with income in both less and greater than 50k.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(pd.crosstab(adult['occupation'],adult['sex']))
print('\n')
pd.crosstab(adult['occupation'],adult['sex']).plot(kind='bar', stacked=True, figsize=(15,8))
plt.xticks(rotation=20)
plt.show()
# Out:
# sex                Female  Male
# occupation
# ?                     841  1002
# Adm-clerical         2537  1233
# Armed-Forces            0     9
# Craft-repair          222  3877
# Exec-managerial      1159  2907
# Farming-fishing        65   929
# Handlers-cleaners     164  1206
# Machine-op-inspct     550  1452
# Other-service        1800  1495
# Priv-house-serv       141     8
# Prof-specialty       1515  2625
# Protective-serv        76   573
# Sales                1263  2387
# Tech-support          348   580
# Transport-moving       90  1507

# %% [markdown]
# - From the plot we can see the females are missing from the Armed-Forces making it an only male occupation.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(pd.crosstab(adult['workclass'],adult['income']))
print('\n')
pd.crosstab(adult['workclass'],adult['income']).plot(kind='bar',figsize=(15,8))
plt.xticks(rotation=0)
plt.show()
# Out:
# income            <=50K  >50K
# workclass
# ?                  1645   191
# Federal-gov         589   371
# Local-gov          1476   617
# Never-worked          7     0
# Private           17733  4963
# Self-emp-inc        494   622
# Self-emp-not-inc   1817   724
# State-gov           945   353
# Without-pay          14     0

# %% [markdown]
# - Private workclass has the most amount of individuals earning both more and less than 50k.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
adult.columns
print(pd.crosstab(adult['marital.status'],adult['income']))
print('\n')
pd.crosstab(adult['marital.status'],adult['income']).plot(kind='bar',figsize=(15,8))
plt.xticks(rotation=0)
plt.show()
# Out:
# income                 <=50K  >50K
# marital.status
# Divorced                3980   463
# Married-AF-spouse         13    10
# Married-civ-spouse      8284  6692
# Married-spouse-absent    384    34
# Never-married          10192   491
# Separated                959    66
# Widowed                  908    85

# %% [markdown]
# - Most individials with marital status as divorced, have an income of less than 50k.
# - Most individuals with marital status as Married-civ-spouse, have an income of more than 50k.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(pd.crosstab(adult['occupation'],adult['income']))
print('\n')
pd.crosstab(adult['occupation'],adult['income']).plot(kind='bar',figsize=(15,8))
plt.xticks(rotation=45)
plt.show()
# Out:
# income             <=50K  >50K
# occupation
# ?                   1652   191
# Adm-clerical        3263   507
# Armed-Forces           8     1
# Craft-repair        3170   929
# Exec-managerial     2098  1968
# Farming-fishing      879   115
# Handlers-cleaners   1284    86
# Machine-op-inspct   1752   250
# Other-service       3158   137
# Priv-house-serv      148     1
# Prof-specialty      2281  1859
# Protective-serv      438   211
# Sales               2667   983
# Tech-support         645   283
# Transport-moving    1277   320

# %% [markdown]
# - Individuals with an occupation of Exec-manegerial and Prof-speciality are the most with a income of more than 50k
# - Individuals with an occupation of Adm-clerical and Craft-repair are the most with an income of less than 50k
